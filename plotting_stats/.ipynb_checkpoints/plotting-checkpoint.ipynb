# %%
# !pip install --upgrade matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Out:
# Requirement already up-to-date: matplotlib in /home/marta/.local/lib/python3.8/site-packages (3.5.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/lib/python3/dist-packages (from matplotlib) (1.0.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7 in /usr/lib/python3/dist-packages (from matplotlib) (2.7.3)
# Requirement already satisfied, skipping upgrade: fonttools>=4.22.0 in /home/marta/.local/lib/python3.8/site-packages (from matplotlib) (4.28.2)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib) (7.0.0)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib) (20.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.17 in /usr/lib/python3/dist-packages (from matplotlib) (1.17.4)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.2.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.6)

# %%
def clean_column_names(data):
    benchmark_data = data.iloc[:, 0]
    benchmark_columns_divided = [line.split('_') for line in benchmark_data]
    print(benchmark_columns_divided)
    def get_entries(which_col):
        entries = [line[which_col] for line in benchmark_columns_divided]
        return entries

    def extract_number(cryptic_name):
        try:
            return int(''.join(filter(str.isdigit, cryptic_name)))
        except ValueError:
            return np.nan
        
    def benchmark_sizes():
        entries = [extract_number(line[1]) for line in benchmark_columns_divided]
        return entries
    
    def benchmark_types():
        entries = [line[1] for line in benchmark_columns_divided]
        return entries
    
    def rob_sizes():
        entries = [extract_number(line[2]) for line in benchmark_columns_divided]
        return entries
    
    def cache_sizes():
        entries = [extract_number(line[3]) for line in benchmark_columns_divided]
        return entries
    
    new_data = data
    new_data['mode'] = pd.Series(get_entries(0))
    new_data['size[k]'] = pd.Series(benchmark_sizes())
    new_data['bench_type'] = pd.Series(benchmark_types())
    new_data['rob_size'] = pd.Series(rob_sizes())
    new_data['l2_cache[kB]'] = pd.Series(cache_sizes())
    
    return new_data
    for col in benchmark_columns_divided:
        print(col)

# %%
def read_data_from_file(filename):
    with open(filename, 'r') as file:
        return pd.read_csv(file)

# data = read_data_from_file('simple2.csv')
data = read_data_from_file('simple2.csv')
# read_data_from_file('../gem5/stats/simple2.csv')
new_data = clean_column_names(data)
plt_size = (18.5, 4.5)
# Out:
# [['base', 'cg', 'rob128', '128kB'], ['base', 'cg', 'rob128', '256kB'], ['base', 'cg', 'rob128', '64kB'], ['base', 'cg', 'rob160', '128kB'], ['base', 'cg', 'rob160', '256kB'], ['base', 'cg', 'rob160', '64kB'], ['base', 'cg', 'rob192', '128kB'], ['base', 'cg', 'rob192', '256kB'], ['base', 'cg', 'rob192', '64kB'], ['base', 'cg', 'rob64', '128kB'], ['base', 'cg', 'rob64', '256kB'], ['base', 'cg', 'rob64', '64kB'], ['base', 'cg', 'rob96', '128kB'], ['base', 'cg', 'rob96', '256kB'], ['base', 'cg', 'rob96', '64kB'], ['base', 'consumer', 'rob128', '128kB'], ['base', 'consumer', 'rob128', '256kB'], ['base', 'consumer', 'rob128', '64kB'], ['base', 'consumer', 'rob160', '128kB'], ['base', 'consumer', 'rob160', '256kB'], ['base', 'consumer', 'rob160', '64kB'], ['base', 'consumer', 'rob192', '128kB'], ['base', 'consumer', 'rob192', '256kB'], ['base', 'consumer', 'rob192', '64kB'], ['base', 'consumer', 'rob64', '128kB'], ['base', 'consumer', 'rob64', '256kB'], ['base', 'consumer', 'rob64', '64kB'], ['base', 'consumer', 'rob96', '128kB'], ['base', 'consumer', 'rob96', '256kB'], ['base', 'consumer', 'rob96', '64kB'], ['base', 'is', 'rob128', '128kB'], ['base', 'is', 'rob128', '256kB'], ['base', 'is', 'rob128', '64kB'], ['base', 'is', 'rob160', '128kB'], ['base', 'is', 'rob160', '256kB'], ['base', 'is', 'rob160', '64kB'], ['base', 'is', 'rob192', '128kB'], ['base', 'is', 'rob192', '256kB'], ['base', 'is', 'rob192', '64kB'], ['base', 'is', 'rob64', '128kB'], ['base', 'is', 'rob64', '256kB'], ['base', 'is', 'rob64', '64kB'], ['base', 'is', 'rob96', '128kB'], ['base', 'is', 'rob96', '256kB'], ['base', 'is', 'rob96', '64kB'], ['base', 'qsort', 'rob128', '128kB'], ['base', 'qsort', 'rob128', '256kB'], ['base', 'qsort', 'rob128', '64kB'], ['base', 'qsort', 'rob160', '128kB'], ['base', 'qsort', 'rob160', '256kB'], ['base', 'qsort', 'rob160', '64kB'], ['base', 'qsort', 'rob192', '128kB'], ['base', 'qsort', 'rob192', '256kB'], ['base', 'qsort', 'rob192', '64kB'], ['base', 'qsort', 'rob64', '128kB'], ['base', 'qsort', 'rob64', '256kB'], ['base', 'qsort', 'rob64', '64kB'], ['base', 'qsort', 'rob96', '128kB'], ['base', 'qsort', 'rob96', '256kB'], ['base', 'qsort', 'rob96', '64kB'], ['base', 'randacc200k', 'rob128', '128kB'], ['base', 'randacc200k', 'rob128', '256kB'], ['base', 'randacc200k', 'rob128', '64kB'], ['base', 'randacc200k', 'rob160', '128kB'], ['base', 'randacc200k', 'rob160', '256kB'], ['base', 'randacc200k', 'rob160', '64kB'], ['base', 'randacc200k', 'rob192', '128kB'], ['base', 'randacc200k', 'rob192', '256kB'], ['base', 'randacc200k', 'rob192', '64kB'], ['base', 'randacc200k', 'rob64', '128kB'], ['base', 'randacc200k', 'rob64', '256kB'], ['base', 'randacc200k', 'rob64', '64kB'], ['base', 'randacc200k', 'rob96', '128kB'], ['base', 'randacc200k', 'rob96', '256kB'], ['base', 'randacc200k', 'rob96', '64kB'], ['base', 'randacc500k', 'rob128', '128kB'], ['base', 'randacc500k', 'rob128', '256kB'], ['base', 'randacc500k', 'rob128', '64kB'], ['base', 'randacc500k', 'rob160', '128kB'], ['base', 'randacc500k', 'rob160', '256kB'], ['base', 'randacc500k', 'rob160', '64kB'], ['base', 'randacc500k', 'rob192', '128kB'], ['base', 'randacc500k', 'rob192', '256kB'], ['base', 'randacc500k', 'rob192', '64kB'], ['base', 'randacc500k', 'rob64', '128kB'], ['base', 'randacc500k', 'rob64', '256kB'], ['base', 'randacc500k', 'rob64', '64kB'], ['base', 'randacc500k', 'rob96', '128kB'], ['base', 'randacc500k', 'rob96', '256kB'], ['base', 'randacc500k', 'rob96', '64kB'], ['base', 'randacc600k', 'rob128', '128kB'], ['base', 'randacc600k', 'rob128', '256kB'], ['base', 'randacc600k', 'rob128', '64kB'], ['base', 'randacc600k', 'rob160', '128kB'], ['base', 'randacc600k', 'rob160', '256kB'], ['base', 'randacc600k', 'rob160', '64kB'], ['base', 'randacc600k', 'rob192', '128kB'], ['base', 'randacc600k', 'rob192', '256kB'], ['base', 'randacc600k', 'rob192', '64kB'], ['base', 'randacc600k', 'rob64', '128kB'], ['base', 'randacc600k', 'rob64', '256kB'], ['base', 'randacc600k', 'rob64' ...

# %%
compare_benchmarks(new_data, ['randacc200k', 'randacc500k',],\
                   'cpi', robsize=128, cachesize=128)
compare_benchmarks(new_data, ['randacc200k', 'randacc500k',],\
                   'cpi', robsize=96, cachesize=128)

# %%
new_data
# Out:
#                   0_config      simTicks    numCycles  iqFullEvents       cpi  \
# 0     base_cg_rob128_128kB  1.187447e+11  315810301.0      397218.0  2.373237
# 1     base_cg_rob128_256kB  1.182408e+11  314470344.0      397248.0  2.363168
# 2      base_cg_rob128_64kB  1.194205e+11  317607787.0      397444.0  2.386745
# 3     base_cg_rob160_128kB  1.074231e+11  285699647.0     2709653.0  2.146964
# 4     base_cg_rob160_256kB  1.069474e+11  284434508.0     2693600.0  2.137457
# ..                     ...           ...          ...           ...       ...
# 355  run_susan_rob64_256kB  2.137804e+10   56856493.0        7152.0  1.503537
# 356   run_susan_rob64_64kB  2.137665e+10   56852782.0        7171.0  1.503438
# 357  run_susan_rob96_128kB  2.121547e+10   56424112.0      157075.0  1.492103
# 358  run_susan_rob96_256kB  2.119576e+10   56371716.0      157065.0  1.490717
# 359   run_susan_rob96_64kB  2.120153e+10   56387048.0      157094.0  1.491122
#
#           ipc    enterRA  totalCyclesRA  cyclesAvgRA  totalDecodedRA  ...  \
# 0    0.421365  3611663.0    227968319.0       63.120      71035746.0  ...
# 1    0.423161  3601549.0    228273569.0       63.382      70847360.0  ...
# 2    0.418981  3615340.0    229034384.0       63.351      71101356.0  ...
# 3    0.465774  3280370.0    198673819.0       60.564      66686490.0  ...
# 4    0.467846  3267189.0    199155564.0       60.956      66654665.0  ...
# ..        ...        ...            ...          ...             ...  ...
# 355  0.665099    13302.0      1817476.0      136.632       2687088.0  ...
# 356  0.665142    13358.0      1807870.0      135.340       2690186.0  ...
# 357  0.670195    13199.0      1658080.0      125.622       2498538.0  ...
# 358  0.670818    13149.0      1671386.0      127.111       2497543.0  ...
# 359  0.670636    13209.0      1658030.0      125.523       2498392.0  ...
#
#      robFullRA  freeRegsAvg  iqFullRa  sstHitsPRE  totalExecutedPRE  mode  \
# 0    3234795.0          NaN       NaN         NaN               NaN  base
# 1    3226058.0          NaN       NaN         NaN               NaN  base
# 2    3236630.0          NaN       NaN         NaN               NaN  base
# 3    1187658.0          NaN       NaN         NaN               NaN  base
# 4    1185860.0          NaN       NaN         NaN               NaN  base
# ..         ...          ...       ...         ...               ...   ...
# 355     2280.0          NaN       NaN         NaN               NaN   run
# 356     2319.0          NaN       NaN         NaN               NaN   run
# 357     1211.0          NaN       NaN         NaN               NaN   run
# 358     1079.0          NaN       NaN         NaN               NaN   run
# 359     1228.0          NaN       NaN         NaN               NaN   run
#
#      size[k]  bench_type  rob_size  l2_cache[kB]
# 0        NaN          cg       128           128
# 1        NaN          cg       128           256
# 2        NaN          cg       128            64
# 3        NaN          cg       160           128
# 4        NaN          cg       160           256
# ..       ...         ...       ...           ...
# 355      NaN       susan        64           256
# 356      NaN       susan        64            64
# 357      NaN       susan        96           128
# 358      NaN       susan        96           256
# 359      NaN       susan        96            64
#
# [360 rows x 26 columns]

# %%
# np.array(new_data['bench_type'])

# %%
# analyze_param(new_data, [], 'cpi', )

# %%
def compare_benchmarks(df, benchmarks, statistic, robsize=128, cachesize=64):
    n_benches = len(benchmarks)

    def find_value(bench_name, statistic, robsize, cachesize, mode):
        good_row = df.loc[(df['bench_type'] == bench_name) & 
                              (df['rob_size'] == robsize) & 
                              (df['l2_cache[kB]'] == cachesize) & 
                              (df['mode'] == mode)]
        
        if len(good_row[statistic]) == 0:
            print("Cannot find a row with benchmark: " + bench_name +\
                            " rob: " + str(robsize) + " l2: " + str(cachesize) +\
                            " mode " + mode)
        try:
            return good_row[statistic].values[0]
        except:
            return 0
                              
    
    def round2(value):
        return round(float(value), 2)
    
    def get_data_for_mode(mode):
        return np.array([round2(find_value(name, statistic, robsize, cachesize, mode)) for name in benchmarks])
        
    pre_scores = get_data_for_mode('pre')
    run_scores = get_data_for_mode('run')
    base_scores = get_data_for_mode('base')

    x = np.arange(len(benchmarks))  # the label locations
    width = 0.35  # the width of the bars
    bottom = 0
    
    fig, ax = plt.subplots()
    fig.set_size_inches(plt_size)
    
    rects1 = ax.bar(x - width/2, base_scores - bottom, width/2, bottom=bottom, label='Baseline')
    rects2 = ax.bar(x,  run_scores - bottom, width/2, bottom=bottom, label='Runahead')
    rects3 = ax.bar(x + width/2, pre_scores - bottom, width/2, bottom=bottom, label='PRE')
    
    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel(statistic.upper())
    ax.set_title("Benchmark comparison.\n L2 size: {}[kB], ROB size: {}".format(cachesize, robsize))
    ax.set_xticks(x, benchmarks)
#     ax.legend(loc='upper right')
    ax.legend(loc='upper right', bbox_to_anchor=(1, 1.1),
          ncol=3, fancybox=True, shadow=True)

    ax.bar_label(rects1, padding=1)
    ax.bar_label(rects2, padding=1)
    ax.bar_label(rects3, padding=1)
    ax.set_xlabel('Benchmark name')
    
    plt.xticks(rotation=90)
    plt.show()
    
# compare_benchmarks(new_data, ['randacc500k', 'randacc600k', 'susan', 'randacc500k'], 'cpi')

compare_benchmarks(new_data, ['susan', 'susanNoRrr', 'susanNoRrrNoSst', 'susanNoSst',\
                              'randacc600k', 'randacc600kNoRrr', 'randacc600kNoRrrNoSst', 'randacc600kNoSst'],\
                   'cpi', robsize=192, cachesize=128)
# Out:
# Cannot find a row with benchmark: susanNoRrr rob: 192 l2: 128 mode pre
# Cannot find a row with benchmark: susanNoRrrNoSst rob: 192 l2: 128 mode pre
# Cannot find a row with benchmark: susanNoSst rob: 192 l2: 128 mode pre
# Cannot find a row with benchmark: randacc600kNoRrr rob: 192 l2: 128 mode pre
# Cannot find a row with benchmark: randacc600kNoRrrNoSst rob: 192 l2: 128 mode pre
# Cannot find a row with benchmark: randacc600kNoSst rob: 192 l2: 128 mode pre
# Cannot find a row with benchmark: susanNoRrr rob: 192 l2: 128 mode run
# Cannot find a row with benchmark: susanNoRrrNoSst rob: 192 l2: 128 mode run
# Cannot find a row with benchmark: susanNoSst rob: 192 l2: 128 mode run
# Cannot find a row with benchmark: randacc600kNoRrr rob: 192 l2: 128 mode run
# Cannot find a row with benchmark: randacc600kNoRrrNoSst rob: 192 l2: 128 mode run
# Cannot find a row with benchmark: randacc600kNoSst rob: 192 l2: 128 mode run
# Cannot find a row with benchmark: susanNoRrr rob: 192 l2: 128 mode base
# Cannot find a row with benchmark: susanNoRrrNoSst rob: 192 l2: 128 mode base
# Cannot find a row with benchmark: susanNoSst rob: 192 l2: 128 mode base
# Cannot find a row with benchmark: randacc600kNoRrr rob: 192 l2: 128 mode base
# Cannot find a row with benchmark: randacc600kNoRrrNoSst rob: 192 l2: 128 mode base
# Cannot find a row with benchmark: randacc600kNoSst rob: 192 l2: 128 mode base

# %%
compare_benchmarks(new_data, ['qsort', 'susan', 'randacc500k', 'randacc600k','cg'],\
                   'cpi', robsize=192, cachesize=128)

# %%
compare_benchmarks(new_data, ['qsort', 'susan', 'randacc500k', 'randacc600k','cg',],\
                   'cpi', robsize=96, cachesize=64)

# %%
# TODO: how to display this nice?? log scale? 
# change to line plot
def analyze_param(df, benchmark, statistic, robsizes=[128], cachesizes=[64]):
    def find_value(bench_name, statistic, robsize, cachesize, mode):
        good_row = df.loc[(df['bench_type'] == bench_name) & 
                          (df['rob_size'] == robsize) & 
                          (df['l2_cache[kB]'] == cachesize) & 
                          (df['mode'] == mode)]

        if len(good_row[statistic]) == 0:
            print("Cannot find a row with benchmark: " + bench_name +\
                            " rob: " + str(robsize) + " l2: " + str(cachesize) +\
                            " mode " + mode)
        try:
            return good_row[statistic].values[0]
        except:
            return 0
    
    def round2(value):
        return round(float(value), 2)
    
    def get_cache_data_for_mode(mode, robsize, cachesizes):
        return np.array([round2(find_value(benchmark, statistic, robsize, c, mode)) for c in cachesizes])
    def get_rob_data_for_mode(mode, robsizes, cachesize):
        return np.array([round2(find_value(benchmark, statistic, r, cachesize, mode)) for r in robsizes])
    
    if len(robsizes) == 1:
        # analyzing cache sizes
        analyze_caches = True
        robsize = robsizes[0]
        pre_scores = get_cache_data_for_mode('pre', robsize, cachesizes)
        run_scores = get_cache_data_for_mode('run', robsize, cachesizes)
        base_scores = get_cache_data_for_mode('base', robsize, cachesizes)
    else:
        assert len(cachesizes) == 1
        analyze_caches = False
        cachesize = cachesizes[0]
        pre_scores = get_rob_data_for_mode('pre', robsizes, cachesize)
        run_scores = get_rob_data_for_mode('run', robsizes, cachesize)
        base_scores = get_rob_data_for_mode('base', robsizes, cachesize)
    
        
    x = np.arange(len(pre_scores))  # the label locations
    width = 0.35  # the width of the bars
    bottom = 0
    
    fig, ax = plt.subplots()
    fig.set_size_inches(plt_size)
    
    rects1 = ax.bar(x - width/2, base_scores - bottom, width/2, bottom=bottom, label='Baseline')
    rects2 = ax.bar(x, run_scores - bottom, width/2, bottom=bottom, label='Runahead')
    rects3 = ax.bar(x + width/2, pre_scores - bottom, width/2, bottom=bottom, label='PRE')
    
    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel(statistic.upper())
    if analyze_caches:
        ax.set_title("L2 cache size[kB] comparison for benchmark {}.\n ROB size: {}".format(benchmark, robsize))    
        ax.set_xticks(x, cachesizes)
        ax.set_xlabel('L2 Cache size')
    else:
        ax.set_title("ROB size comparison for benchmark {}.\n L2 cache size [kB]: {}".format(benchmark, cachesize))
        ax.set_xticks(x, robsizes)
        ax.set_xlabel('ROB size')
        
    ax.legend(loc='upper right', bbox_to_anchor=(1, 1.1),
          ncol=3, fancybox=True, shadow=True)

    ax.bar_label(rects1, padding=1)
    ax.bar_label(rects2, padding=1)
    ax.bar_label(rects3, padding=1)

    plt.show()

# %%
def analyze_all(data, stat, robs, caches):
    analyze_param(data, 'randacc200k', stat, robsizes=robs, cachesizes=caches)
    analyze_param(data, 'randacc500k', stat, robsizes=robs, cachesizes=caches)
    analyze_param(data, 'randacc600k', stat, robsizes=robs, cachesizes=caches)
    analyze_param(data, 'susan', stat, robsizes=robs, cachesizes=caches)
    analyze_param(data, 'qsort', stat, robsizes=robs, cachesizes=caches)
    analyze_param(data, 'cg', stat, robsizes=robs, cachesizes=caches)

# %%
robs = [64, 96, 128, 160, 192]
cache = [128]
analyze_all(new_data, 'ipc', robs, cache)

# %%
robs = [64, 96, 128, 160, 192]
cache = [128]
analyze_all(new_data, 'numCycles', robs, cache)

# %%
robs = [64, 96, 128, 160, 192]
cache = [128]
analyze_all(new_data, 'totalCyclesRA', robs, cache)

# %%
caches = [64, 128, 256]
rob = [128]
analyze_all(new_data, 'ipc', rob, caches)

# %%
# TODO make this nicer :) colors, scaling so that differences are visible??
# change to percentage? i.e. 100% = x+y, x is the normal mode part, y the runahead mode part
def cache_misses_benchmarks(df, benchmarks, robsize=128, cachesize=64):

    def find_value(bench_name, statistic, robsize, cachesize, mode):
        good_row = df.loc[(df['bench_type'] == bench_name) & 
                              (df['rob_size'] == robsize) & 
                              (df['l2_cache[kB]'] == cachesize) & 
                              (df['mode'] == mode)]
        
        if len(good_row[statistic]) == 0:
            print("Cannot find a row with benchmark: " + bench_name +\
                            " rob: " + str(robsize) + " l2: " + str(cachesize) +\
                            " mode " + mode)
        try:
            return good_row[statistic].values[0]
        except:
            return 0
                              
    
    def round2(value):
        return round(float(value), 2)
    
    def get_data_for_mode(mode, stat):
        return np.array([round2(find_value(name, stat, robsize, cachesize, mode)) for name in benchmarks])
        
    n_benches = len(benchmarks)
    stats = [('l1Miss', 'l1MissRA'), ('l2Miss', 'l2MissRA')]
    for (x,y) in stats:
        pre_scores = get_data_for_mode('pre', x)
        pre_scores_RA = get_data_for_mode('pre', y)
        run_scores = get_data_for_mode('run', x)
        run_scores_RA = get_data_for_mode('run', y)
        base_scores = get_data_for_mode('base', x)
        base_scores_RA = get_data_for_mode('base', y)

        vals = np.arange(len(benchmarks))  # the label locations
        width = 0.35  # the width of the bars
        

        fig, ax = plt.subplots()
        fig.set_size_inches(plt_size)

        rects1  = ax.bar(vals - width/2, base_scores, width/2, bottom=0, label='Baseline')
        rects11 = ax.bar(vals - width/2, base_scores_RA, width/2, bottom=base_scores, label='Baseline miss RA')
        rects2  = ax.bar(vals,  run_scores, width/2, bottom=0, label='Runahead')
        rects22 = ax.bar(vals,  run_scores_RA, width/2, bottom=run_scores, label='RA miss in RA')
        rects3  = ax.bar(vals + width/2, pre_scores, width/2, bottom=0, label='PRE')
        rects33 = ax.bar(vals + width/2, pre_scores_RA, width/2, bottom=pre_scores, label='PRE miss in PRE')

        # Add some text for labels, title and custom x-axis tick labels, etc.
        ax.set_ylabel(x.upper())
        ax.set_title("Benchmark comparison.\n L2 size: {}[kB], ROB size: {}".format(cachesize, robsize))
        ax.set_xticks(vals, benchmarks)
        ax.legend(loc='upper right', bbox_to_anchor=(1, 1.1),
              ncol=3, fancybox=True, shadow=True)

        ax.bar_label(rects1, padding=1)
        ax.bar_label(rects2, padding=1)
        ax.bar_label(rects3, padding=1)
        ax.set_xlabel('Benchmark name')

        plt.xticks(rotation=90)
        print(x)
        plt.show()
    
    
cache_misses_benchmarks(new_data, ['qsort', 'susan', 'randacc500k', 'randacc600k',],\
                   robsize=96, cachesize=128)
# Out:
# l1Miss
# l2Miss

# %%
cache_misses_benchmarks(new_data, ['randacc500k',],\
                   robsize=96, cachesize=64)
# Out:
# l1Miss
# l2Miss
